# %%
import pandas as pd

# %%
data1 = pd.DataFrame({
    "id":[1,2,3,4],
    "name":["harry","ram","Shyam","gita"]
})

data2 = pd.DataFrame({
    "id":[2,3,4,5],
    "marks":[24,56,76,98]
})

merged = pd.merge(data1,data2,on="id")
print(merged)
